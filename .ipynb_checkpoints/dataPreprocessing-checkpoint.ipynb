# %%
import requests
import pandas as pd
from io import StringIO

# %%
# --- Location and date setup ---

# %%
locations = [
    "Paro", "Gasa", "Deothang", "Bhur", "Nganglam", "Zhemgang", "Simtokha",
    "Phuentsholing", "Chamkhar", "Kanglung_Tashigang", "Mongar", "Trongsa",
    "Tashiyangtse", "Tangmachu_Lhuentse"
]

# %%
latitudes = [
    27.43,  # Paro
    27.91,  # Gasa
    26.88,  # Deothang
    26.85,  # Bhur
    27.05,  # Nganglam
    27.21,  # Zhemgang
    27.46,  # Simtokha
    26.86,  # Phuentsholing
    27.56,  # Chamkhar
    27.26,  # Kanglung (Trashigang)
    27.27,  # Mongar
    27.50,  # Trongsa
    27.63,  # Tashiyangtse
    27.77   # Tangmachu (Lhuentse)
]

longitudes = [
    89.42,  # Paro
    89.73,  # Gasa
    91.56,  # Deothang
    90.56,  # Bhur
    91.20,  # Nganglam
    90.67,  # Zhemgang
    89.64,  # Simtokha
    89.39,  # Phuentsholing
    90.73,  # Chamkhar
    91.23,  # Kanglung (Trashigang)
    91.25,  # Mongar
    90.50,  # Trongsa
    91.51,  # Tashiyangtse
    91.01   # Tangmachu (Lhuentse)
]

# %%
startDate = "20010101"
endDate = "20250601"

# %%
# --- Only the parameters you requested ---
parameters = ",".join([
    "PRECTOTCORR",  # Rainfall
    "T2M",          # Temperature at 2m
    "CLOUD_AMT",    # Cloud cover
    "RH2M",         # Humidity
    "ALLSKY_SFC_SW_DWN"  # Solar radiation
])

# %%
# --- API URL ---
url = (
    f"https://power.larc.nasa.gov/api/temporal/daily/point?"
    f"parameters={parameters}&start={start_date}&end={end_date}"
    f"&latitude={latitude}&longitude={longitude}&community=AG&format=JSON"
)

# --- Fetch data ---
response = requests.get(url)
data = response.json()

# --- Extract values ---
records = data["properties"]["parameter"]
dates = list(records["T2M"].keys())  # Use any param to get date keys
df = pd.DataFrame({'date': pd.to_datetime(dates)})

# --- Add each parameter to the DataFrame ---
for param in parameters.split(","):
    if param in records:
        df[param] = [records[param].get(date) for date in dates]
    else:
        df[param] = None  # Fallback if param is missing

# --- Add lat/lon info ---
df["latitude"] = latitude
df["longitude"] = longitude

# --- Save to CSV ---
df.to_csv("gasa_nasa_selected_data_2023.csv", index=False)
print("✅ Data saved to gasa_nasa_selected_data_2023.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 13
#      10 data = response.json()
#      12 # --- Extract values ---
# ---> 13 records = data["properties"]["parameter"]
#      14 dates = list(records["T2M"].keys())  # Use any param to get date keys
#      15 df = pd.DataFrame({'date': pd.to_datetime(dates)})
#
# KeyError: 'properties'

# %%
class FetchNASAAPIData:
    def __init__(self, latitude, longitude, parameters):
        self.latitude=latitude
        self.longitude=longitude
        self.parameters=parameters

    def generateAPIURL(self, startDate, endDate, latitude, longitude, dataFormat="JSON"):
        url = (
                f"https://power.larc.nasa.gov/api/temporal/daily/point?"
                f"parameters={self.parameters}&start={startDate}&end={endDate}"
                f"&latitude={latitude}&longitude={longitude}&community=AG&format={dataFormat}"
            )
        return url

# %%
fetchNASA = FetchNASAAPIData(latitude, longitude, parameters)

# %%
fetchNASA.generateAPIURL(startDate, endDate, latitudes[0], longitudes[0])
# Out:
# 'https://power.larc.nasa.gov/api/temporal/daily/point?parameters=PRECTOTCORR,T2M,CLOUD_AMT,RH2M,TS,PS,T2MWET,WS2M,WS50M,ALLSKY_SFC_SW_DWN&start=20010101&end=20250601&latitude=27.43&longitude=89.42&community=AG&format=JSON'

# %%
response = requests.get(fetchNASA.generateAPIURL(startDate, endDate, latitudes[0], longitudes[0]))

# %%
data=response.json()

# %%
response.json()
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [89.42, 27.43, 3436.91]},
#  'properties': {'parameter': {'PRECTOTCORR': {'20010101': 0.11,
#     '20010102': 0.34,
#     '20010103': 0.0,
#     '20010104': 0.01,
#     '20010105': 0.0,
#     '20010106': 0.0,
#     '20010107': 0.0,
#     '20010108': 0.0,
#     '20010109': 0.0,
#     '20010110': 0.0,
#     '20010111': 0.0,
#     '20010112': 0.0,
#     '20010113': 0.0,
#     '20010114': 0.0,
#     '20010115': 0.0,
#     '20010116': 0.0,
#     '20010117': 0.0,
#     '20010118': 0.0,
#     '20010119': 0.0,
#     '20010120': 0.0,
#     '20010121': 0.0,
#     '20010122': 0.03,
#     '20010123': 0.07,
#     '20010124': 0.0,
#     '20010125': 0.0,
#     '20010126': 0.0,
#     '20010127': 0.0,
#     '20010128': 0.0,
#     '20010129': 0.0,
#     '20010130': 0.0,
#     '20010131': 0.0,
#     '20010201': 0.0,
#     '20010202': 0.0,
#     '20010203': 0.0,
#     '20010204': 0.0,
#     '20010205': 0.0,
#     '20010206': 0.0,
# ...

# %%
# Define the column names
columns = [
    "date",
    "longitude",
    "latitude",
    "Rain",
    "T2M",            
    "CLOUD_AMT",       
    "RH2M",          
    "ALLSKY_SFC_SW_DWN",
    "Elevation",
    "district"
]

# Create an empty DataFrame with these columns
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [date, longitude, latitude, Rain, T2M, CLOUD_AMT, RH2M, ALLSKY_SFC_SW_DWN, Elevation, district]
# Index: []

# %%
data["geometry"]["coordinates"]
# Out:
# [89.42, 27.43, 3436.91]

# %%
data["properties"]["parameter"]["PRECTOTCORR"]
# Out:
# {'20010101': 0.11,
#  '20010102': 0.34,
#  '20010103': 0.0,
#  '20010104': 0.01,
#  '20010105': 0.0,
#  '20010106': 0.0,
#  '20010107': 0.0,
#  '20010108': 0.0,
#  '20010109': 0.0,
#  '20010110': 0.0,
#  '20010111': 0.0,
#  '20010112': 0.0,
#  '20010113': 0.0,
#  '20010114': 0.0,
#  '20010115': 0.0,
#  '20010116': 0.0,
#  '20010117': 0.0,
#  '20010118': 0.0,
#  '20010119': 0.0,
#  '20010120': 0.0,
#  '20010121': 0.0,
#  '20010122': 0.03,
#  '20010123': 0.07,
#  '20010124': 0.0,
#  '20010125': 0.0,
#  '20010126': 0.0,
#  '20010127': 0.0,
#  '20010128': 0.0,
#  '20010129': 0.0,
#  '20010130': 0.0,
#  '20010131': 0.0,
#  '20010201': 0.0,
#  '20010202': 0.0,
#  '20010203': 0.0,
#  '20010204': 0.0,
#  '20010205': 0.0,
#  '20010206': 0.0,
#  '20010207': 0.0,
#  '20010208': 0.0,
#  '20010209': 0.0,
#  '20010210': 0.0,
#  '20010211': 0.0,
#  '20010212': 0.0,
#  '20010213': 0.0,
#  '20010214': 0.0,
#  '20010215': 0.0,
#  '20010216': 0.0,
#  '20010217': 0.0,
#  '20010218': 0.35,
# ...
